# %% [markdown]
# Importing Necessary Library

# %%
# Importing Necessary Libraries
import wandb
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from keras.applications import resnet
from tensorflow.keras.applications import VGG16, ResNet50, ResNet101, InceptionResNetV2
from tensorflow.keras.layers import AveragePooling2D, MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os

# %% [markdown]
# Loading the Dataset

# %%
config = {
    'path_dir': "/kaggle/input/monkeypox/converted_data"
}
config
# Out:
# {'path_dir': '/kaggle/input/monkeypox/converted_data'}

# %%
# Initialize Weights & Biases
wandb.login(key="43ba0e8a2e5913526b62f3733783d0f493c6c39a")
wandb.init(project="final-project-ablations", name="dnyaboke_project_trial5")

print("[INFO] loading images...")
imagePaths = list(paths.list_images(config['path_dir']))
data = []
labels = []

print(f"Number of image paths loaded: {len(imagePaths)}")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250316_195344-gnb01le6</code>
# Syncing run <strong><a href='https://wandb.ai/delta-group-50/final-project-ablations/runs/gnb01le6' target="_blank">dnyaboke_project_trial5</a></strong> to <a href='https://wandb.ai/delta-group-50/final-project-ablations' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/delta-group-50/final-project-ablations' target="_blank">https://wandb.ai/delta-group-50/final-project-ablations</a>
#  View run at <a href='https://wandb.ai/delta-group-50/final-project-ablations/runs/gnb01le6' target="_blank">https://wandb.ai/delta-group-50/final-project-ablations/runs/gnb01le6</a>
# [INFO] loading images...
# Number of image paths loaded: 90

# %%
# Define paths directly
root_dir = config["path_dir"]
monkeypox_label = "Monkeypox_gray"
monkeypox_path = f"{root_dir}/{monkeypox_label}"
# chickenpox_path = f"config["path_dir"]/chicken_pox"
chickenpox_label = "Chickenpox_grayscale" #"chicken_pox"
chickenpox_path = f"{root_dir}/{chickenpox_label}"

# Function to load images from a directory with a specific label
def load_images_from_folder(folder, label):
    images = []
    labels_list = []
    count = 0

    # Check if directory exists
    if not os.path.exists(folder):
        print(f"Warning: {folder} directory does not exist")
        return images, labels_list

    # Load all images from the directory
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        if os.path.isfile(img_path):
            image = cv2.imread(img_path)
            if image is not None:
                image = cv2.resize(image, (224, 224))  # Resize to match VGG16 input
                images.append(image)
                labels_list.append(label)
                count += 1

    print(f"Loaded {count} images from {folder}")
    return images, labels_list

# Load Chickenpox images
chickenpox_images, chickenpox_labels = load_images_from_folder(chickenpox_path, chickenpox_label)

# Load Monkeypox images
monkeypox_images, monkeypox_labels = load_images_from_folder(monkeypox_path, monkeypox_label)

# Combine the data
data = chickenpox_images + monkeypox_images
labels = chickenpox_labels + monkeypox_labels

# Convert to numpy arrays
data = np.array(data, dtype="float32") / 255.0  # Normalize pixel values
labels = np.array(labels)

print(f"Final dataset size: {len(data)} images")
print(f"Unique labels: {np.unique(labels)}")
print(f"Label counts: {[(label, (labels == label).sum()) for label in np.unique(labels)]}")
# Out:
# Loaded 47 images from /kaggle/input/monkeypox/converted_data/Chickenpox_grayscale
# Loaded 43 images from /kaggle/input/monkeypox/converted_data/Monkeypox_gray
# Final dataset size: 90 images
# Unique labels: ['Chickenpox_grayscale' 'Monkeypox_gray']
# Label counts: [('Chickenpox_grayscale', 47), ('Monkeypox_gray', 43)]

# %% [markdown]
# Image preprocessing and extract the Label

# %%
# Create dictionaries to store data by class
class_data = {monkeypox_label: [], chickenpox_label: []}
for img, lbl in zip(data, labels):
    class_data[lbl].append(img)

# Create train and test sets with specific counts
trainX = []
testX = []
trainY = []
testY = []

# Monkeypox: 34 train, 9 test
monkey_images = class_data[monkeypox_label]
if len(monkey_images) >= 43:
    monkey_train = monkey_images[:34]
    monkey_test = monkey_images[34:43]
    trainX.extend(monkey_train)
    testX.extend(monkey_test)
    trainY.extend([monkeypox_label] * len(monkey_train))
    testY.extend([monkeypox_label] * len(monkey_test))
else:
    print(f"Warning: Not enough Monkeypox images. Found {len(monkey_images)}, need 43")

# Chickenpox: 38 train, 9 test
chicken_images = class_data[chickenpox_label]
if len(chicken_images) >= 47:
    chicken_train = chicken_images[:38]
    chicken_test = chicken_images[38:47]
    trainX.extend(chicken_train)
    testX.extend(chicken_test)
    trainY.extend([chickenpox_label] * len(chicken_train))
    testY.extend([chickenpox_label] * len(chicken_test))
else:
    print(f"Warning: Not enough Chickenpox images. Found {len(chicken_images)}, need 47")

# Convert to numpy arrays
trainX = np.array(trainX, dtype="float32")
testX = np.array(testX, dtype="float32")
trainY = np.array(trainY)
testY = np.array(testY)

print(f"Train data shape: {trainX.shape}, Train labels shape: {trainY.shape}")
print(f"Test data shape: {testX.shape}, Test labels shape: {testY.shape}")
# Out:
# Train data shape: (72, 224, 224, 3), Train labels shape: (72,)
# Test data shape: (18, 224, 224, 3), Test labels shape: (18,)

# %%
# Convert labels to categorical (if needed)
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)
trainY = to_categorical(trainY)
testY = to_categorical(testY)

# # Initialize the training data augmentation object
# trainAug = ImageDataGenerator(
#     rotation_range=45, 
#     width_shift_range=0.02, 
#     height_shift_range=0.02, 
#     zoom_range=0.02, 
#     horizontal_flip=True, 
#     fill_mode="nearest"
# )

# %%
# baseModel =VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
# #baseModel =ResNet50(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
# # baseModel =ResNet101(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
# # baseModel =InceptionResNetV2(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
# headModel = baseModel.output
# # headModel = AveragePooling2D(pool_size=(4, 4))(headModel)
# headModel = MaxPooling2D(pool_size=(4, 4))(headModel)
# headModel = Flatten(name="flatten")(headModel)
# headModel = Dense(64, activation="relu")(headModel)
# headModel = Dropout(0.5)(headModel)
# headModel = Dense(2, activation="softmax")(headModel)
# model = Model(inputs=baseModel.input, outputs=headModel)
# for layer in baseModel.layers:
# 	layer.trainable = False
# 	# compile our model

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout
from tensorflow.keras.models import Model

# 1) Load pre-trained VGG16 (convolution + maxpool only; no Dense "top")
baseModel = VGG16(weights="imagenet", include_top=False,
                  input_tensor=Input(shape=(224, 224, 3)))

# 2) Build your "modified" classification head:
headModel = baseModel.output
# Optionally remove your custom MaxPool(4x4), as VGG16 already has max pool layers.
# headModel = MaxPooling2D(pool_size=(4, 4))(headModel)  # (Likely remove this if you want standard flow)

headModel = Flatten(name="flatten")(headModel)
headModel = Dense(512, activation="relu")(headModel)   # 1st Dense
headModel = Dropout(0.5)(headModel)                    # Dropout
headModel = Dense(256, activation="relu")(headModel)   # 2nd Dense
headModel = Dense(128, activation="relu")(headModel)   # 3rd Dense
headModel = Dense(2, activation="softmax")(headModel)  # Final classification

# 3) Combine base + new head
model = Model(inputs=baseModel.input, outputs=headModel)

# 4) Freeze the base model layers for initial training
for layer in baseModel.layers:
    layer.trainable = False

# # 5) Compile
# model.compile(optimizer="adam", loss="categorical_crossentropy", 
#               metrics=["accuracy"])

# %%
# model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │          32,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,747,650 (56.26 MB)
#  Trainable params: 32,962 (128.76 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
INIT_LR = 1e-3
EPOCHS = 100
BS = 30

# %%
# INIT_LR = 0.001
# EPOCHS = 35
# BS = 10

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import tensorflow as tf
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# #opt = tf.keras.optimizers.SGD(learning_rate=INIT_LR)
# opt = tf.keras.optimizers.RMSprop(learning_rate=INIT_LR)



# opt = Adam(learning_rate=INIT_LR)

# %%
# Compile the model
print("[INFO] compiling model...")
# model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
model.compile(optimizer="adam", loss="categorical_crossentropy", 
              metrics=["accuracy"])

# # Start timing
# t1 = time.process_time()

# Train the model
print("[INFO] training head...")
wandb_callback = wandb.keras.WandbMetricsLogger(log_freq="epoch")
import time
t1=time.process_time()
H = model.fit(
    x=trainX, 
    y=trainY, 
    batch_size=BS,
    steps_per_epoch=len(trainX) // BS,
    validation_data=(testX, testY),
    validation_steps=len(testX) // BS,
    epochs=EPOCHS,
     callbacks=[wandb_callback]
)

# End timing
t2 = time.process_time()
print("Process time:", t2 - t1)
# Out:
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.5889 - loss: 1.5091 - val_accuracy: 0.5000 - val_loss: 3.3726
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6667 - loss: 2.2727 - val_accuracy: 0.5000 - val_loss: 2.3952
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5667 - loss: 1.8107 - val_accuracy: 0.5000 - val_loss: 3.1136
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5833 - loss: 2.3009 - val_accuracy: 0.5000 - val_loss: 2.4933
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5667 - loss: 1.6983 - val_accuracy: 0.5000 - val_loss: 0.8522
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5000 - loss: 1.3077 - val_accuracy: 0.5000 - val_loss: 1.2203
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4667 - loss: 1.5687 - val_accuracy: 0.5000 - val_loss: 0.7741
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4167 - loss: 1.3539 - val_accuracy: 0.5000 - val_loss: 1.1259
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5889 - loss: 1.1186 - val_accuracy: 0.5000 - val_loss: 0.7024
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8333 - loss: 0.7203 - val_accuracy: 0.7778 - val_loss: 0.5512
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6222 - loss: 0.7511 - val_accuracy: 0.5000 - val_loss: 0.8573
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6667 - loss: 0.6631 - val_accuracy: 0.5556 - val_loss: 0.6172
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6444 - loss: 0.8360 - val_accuracy: 0.5000 - val_loss: 0.7943
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4167 - loss: 1.2419 - val_accuracy: 0.5000 - val_loss: 0.7775
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.7111 - loss: 0.7950 - val_accuracy: 0.7778 - val_loss: 0.5310
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6667 - loss: 0.8397 - val_accuracy: 0.7222 - val_loss: 0.5349
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7000 - loss: 0.6989 - val_accuracy: 0.7778 - val_loss: 0.5272
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6667 - loss: 0.9163 - val_accuracy: 0.8333 - val_loss: 0.5210
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5222 - loss: 0.8235 - val_accuracy: 0.8333 - val_loss: 0.4877
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8333 - loss: 0.4725 - val_accuracy: 0.7222 - val_loss: 0.4934
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7000 - loss: 0.5960 - val_accuracy: 0.8333 - val_loss: 0.4969
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8333 - loss: 0.3559 - val_accuracy: 0.6667 - val_loss: 0.5325
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8333 - loss: 0.4317 - val_accuracy: 0.7778 - val_loss: 0.4358
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7500 - loss: 0.4637 - val_accuracy: 0.8333 - val_loss: 0.4485
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8444 - loss: 0.3429 - val_accuracy: 0.7778 - val_loss: 0.4377
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6667 - loss: 0.6857 - val_accuracy: 0.7778 - val_loss: 0.5059
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8889 - loss: 0.2468 - val_accuracy: 0.7778 - val_loss: 0.5323
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0737 - val_accuracy: 0.7778 - val_loss: 0.5055
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8000 - loss: 0.4648 - val_accuracy: 0.8333 - val_loss: 0.4027
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.1307 - val_accuracy: 0.7778 - val_loss: 0.3991
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7556 - loss: 0.4273 - val_accuracy: 0.7778 - val_loss: 0.4130
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8333 - loss: 0.2517 - val_accuracy: 0.7222 - val_loss: 0.4527
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9111 - loss: 0.2614 - val_accuracy: 0.7778 - val_loss: 0.5290
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6667 - loss: 0.4421 - val_accuracy: 0.7778 - val_loss: 0.3937
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9111 - loss: 0.2007 - val_accuracy: 0.8333 - val_loss: 0.4020
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8333 - loss: 0.3976 - val_accuracy: 0.8333 - val_loss: 0.3652
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9222 - loss: 0.1662 - val_accuracy: 0.7778 - val_loss: 0.4447
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8333 - loss: 0.2172 - val_accuracy: 0.7778 - val_loss: 0.6069
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9222 - loss: 0.2422 - val_accuracy: 0.7778 - val_loss: 0.6574
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9167 - loss: 0.2620 - val_accuracy: 0.7778 - val_loss: 0.5204
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9889 - loss: 0.0787 - val_accuracy: 0.8333 - val_loss: 0.4191
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9167 - loss: 0.3076 - val_accuracy: 0.7778 - val_loss: 0.4268
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9667 - loss: 0.1095 - val_accuracy: 0.7778 - val_loss: 0.4471
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0575 - val_accuracy: 0.7778 - val_loss: 0.4948
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9444 - loss: 0.1791 - val_accuracy: 0.8333 - val_loss: 0.5513
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9167 - loss: 0.1246 - val_accuracy: 0.7778 - val_loss: 0.4920
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9778 - loss: 0.1605 - val_accuracy: 0.7778 - val_loss: 0.4217
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9167 - loss: 0.3477 - val_accuracy: 0.7778 - val_loss: 0.4236
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9444 - loss: 0.1322 - val_accuracy: 0.7778 - val_loss: 0.5066
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0305 - val_accuracy: 0.8333 - val_loss: 0.5917
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9333 - loss: 0.2053 - val_accuracy: 0.8333 - val_loss: 0.6616
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0486 - val_accuracy: 0.8333 - val_loss: 0.6131
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9444 - loss: 0.1584 - val_accuracy: 0.7778 - val_loss: 0.4435
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9167 - loss: 0.1027 - val_accuracy: 0.8333 - val_loss: 0.4120
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9667 - loss: 0.1590 - val_accuracy: 0.7778 - val_loss: 0.4373
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.7778 - val_loss: 0.4575
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9222 - loss: 0.1237 - val_accuracy: 0.7778 - val_loss: 0.4206
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0561 - val_accuracy: 0.7778 - val_loss: 0.4341
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9222 - loss: 0.1623 - val_accuracy: 0.7778 - val_loss: 0.5765
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0425 - val_accuracy: 0.7222 - val_loss: 0.6558
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9667 - loss: 0.0642 - val_accuracy: 0.7778 - val_loss: 0.7144
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0713 - val_accuracy: 0.7778 - val_loss: 0.7128
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9222 - loss: 0.2491 - val_accuracy: 0.7222 - val_loss: 0.6355
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9167 - loss: 0.2155 - val_accuracy: 0.7222 - val_loss: 0.5212
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9778 - loss: 0.0827 - val_accuracy: 0.8333 - val_loss: 0.4693
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0563 - val_accuracy: 0.8333 - val_loss: 0.4706
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8889 - loss: 0.2667 - val_accuracy: 0.7778 - val_loss: 0.5362
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0296 - val_accuracy: 0.7778 - val_loss: 0.5935
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9667 - loss: 0.0779 - val_accuracy: 0.7778 - val_loss: 0.7375
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0448 - val_accuracy: 0.7222 - val_loss: 0.8182
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9667 - loss: 0.0896 - val_accuracy: 0.7222 - val_loss: 0.8132
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.7778 - val_loss: 0.7735
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8778 - loss: 0.2305 - val_accuracy: 0.7778 - val_loss: 0.6169
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.7778 - val_loss: 0.5805
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9667 - loss: 0.1090 - val_accuracy: 0.7778 - val_loss: 0.5198
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.7778 - val_loss: 0.4913
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9556 - loss: 0.0617 - val_accuracy: 0.7778 - val_loss: 0.4631
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.7778 - val_loss: 0.4637
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9667 - loss: 0.0758 - val_accuracy: 0.7778 - val_loss: 0.5020
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9167 - loss: 0.1323 - val_accuracy: 0.7778 - val_loss: 0.6052
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9333 - loss: 0.1100 - val_accuracy: 0.7222 - val_loss: 0.7792
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.7222 - val_loss: 0.8425
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9889 - loss: 0.0767 - val_accuracy: 0.7778 - val_loss: 0.7686
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9167 - loss: 0.5630 - val_accuracy: 0.7778 - val_loss: 0.5990
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9667 - loss: 0.0731 - val_accuracy: 0.7778 - val_loss: 0.4495
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.8333 - val_loss: 0.4909
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9556 - loss: 0.0650 - val_accuracy: 0.7222 - val_loss: 0.6628
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8333 - loss: 0.5701 - val_accuracy: 0.8333 - val_loss: 0.5470
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9333 - loss: 0.1782 - val_accuracy: 0.7222 - val_loss: 0.5951
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.7778 - val_loss: 0.8281
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9778 - loss: 0.1971 - val_accuracy: 0.7222 - val_loss: 1.1440
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.1093 - val_accuracy: 0.7222 - val_loss: 1.0774
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9667 - loss: 0.2285 - val_accuracy: 0.7778 - val_loss: 0.8605
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0494 - val_accuracy: 0.7778 - val_loss: 0.7937
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.7222 - val_loss: 0.6950
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9167 - loss: 0.7089 - val_accuracy: 0.7222 - val_loss: 0.5898
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9778 - loss: 0.0614 - val_accuracy: 0.7778 - val_loss: 0.5057
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0304 - val_accuracy: 0.7778 - val_loss: 0.5017
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9778 - loss: 0.0311 - val_accuracy: 0.7778 - val_loss: 0.5050
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7778 - val_loss: 0.5083
# Process time: 24.93492409400001

# %%
print(len(H.history['loss']))
# Out:
# 100

# %%
model.save_weights("my_model_weights.weights.h5")

# %%
# Log model weights to W&B as an artifact
artifact = wandb.Artifact("monkeypox-model", type="model")
artifact.add_file("my_model_weights.weights.h5")
wandb.log_artifact(artifact)

#classification report on training
predIdxs = model.predict(trainX)
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
trainpredict = np.argmax(predIdxs, axis=1)
print(classification_report(trainY.argmax(axis=1), trainpredict,
	target_names=lb.classes_))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step
#                       precision    recall  f1-score   support
#
# Chickenpox_grayscale       1.00      0.95      0.97        38
#       Monkeypox_gray       0.94      1.00      0.97        34
#
#             accuracy                           0.97        72
#            macro avg       0.97      0.97      0.97        72
#         weighted avg       0.97      0.97      0.97        72

# %%
# compute the confusion matrix and and use it to derive the raw
# accuracy, sensitivity, and specificity
cm = confusion_matrix(trainY.argmax(axis=1), trainpredict)
total = sum(sum(cm))
print(cm)
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
# show the confusion matrix, accuracy, sensitivity, and specificity
print("acc: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))

# Log metrics to W&B
wandb.log({
    "train_accuracy": acc,
    "train_sensitivity": sensitivity,
    "train_specificity": specificity
})
# Out:
# [[36  2]
#  [ 0 34]]
# acc: 0.9722
# sensitivity: 0.9474
# specificity: 1.0000

# %%
# make predictions on the testing set
print("[INFO] evaluating network...")
predIdys = model.predict(testX, batch_size=BS)
testpredict = np.argmax(predIdys, axis=1)
print(classification_report(testY.argmax(axis=1), testpredict,
	target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
#                       precision    recall  f1-score   support
#
# Chickenpox_grayscale       0.73      0.89      0.80         9
#       Monkeypox_gray       0.86      0.67      0.75         9
#
#             accuracy                           0.78        18
#            macro avg       0.79      0.78      0.77        18
#         weighted avg       0.79      0.78      0.77        18

# %%
# compute the confusion matrix and and use it to derive the raw
# accuracy, sensitivity, and specificity
cm = confusion_matrix(testY.argmax(axis=1), testpredict)
total = sum(sum(cm))
print(cm)
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
# show the confusion matrix, accuracy, sensitivity, and specificity
print("acc: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))

# Log test metrics to W&B
wandb.log({
    "test_accuracy": acc,
    "test_sensitivity": sensitivity,
    "test_specificity": specificity
})
# Out:
# [[8 1]
#  [3 6]]
# acc: 0.7778
# sensitivity: 0.8889
# specificity: 0.6667

# %%
from sklearn import metrics
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
fig = plt.figure(figsize = (4, 3))
fpr1,tpr1,_=roc_curve(np.argmax(trainY, axis=1),np.argmax(predIdxs, axis=1))
fpr2,tpr2,_=roc_curve(np.argmax(testY, axis=1),np.argmax(predIdys, axis=1))
area_under_curve1=auc(fpr1,tpr1)
random_probs=[0 for i in range(len(trainY.ravel()))]
p_fpr1,p_tpr1,threshold=roc_curve(trainY.ravel(),random_probs, pos_label=1)
plt.plot(fpr1,tpr1, label='Train AUC = {:.3f}'.format(area_under_curve1))
plt.plot(p_fpr1, p_tpr1)
area_under_curve2=auc(fpr2,tpr2)
random_probs2=[0 for i in range(len(testY.ravel()))]
p_fpr2,p_tpr2,threshold=roc_curve(testY.ravel(),random_probs2, pos_label=1)
plt.plot(fpr2,tpr2, label='Test AUC = {:.3f}'.format(area_under_curve2))
plt.plot(p_fpr2, p_tpr2)

    # x label
plt.xlabel('FPR',fontsize=14, fontdict=dict(weight='bold'))
    # y label
plt.ylabel('TPR', fontsize=14, fontdict=dict(weight='bold'))
plt.xticks( rotation=0, weight = 'bold', )
plt.yticks( rotation=0, weight = 'bold')
plt.tick_params(rotation=0,axis='y', labelsize=12)
plt.tick_params(rotation=0,axis='x', labelsize=12)
plt.legend()
plt.legend(prop={'size':12})
plt.savefig('ROC',dpi=200, bbox_inches='tight')
plt.show();

# Log ROC curve to W&B
wandb.log({"ROC_curve": wandb.Image(plt)})

# %%
from matplotlib.ticker import FormatStrFormatter

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

N=len(H.history['loss'])
fig, ax = plt.subplots()
#plt.rcParams["font.family"] = "serif"
acc = H.history['accuracy']
val_acc = H.history['val_accuracy']
#font={'size':10}
#matplotlib.rc('font',**font)
loss = H.history['loss']
val_loss = H.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(np.arange(0, N), H.history["accuracy"], label="TA")
#plt.plot(epochs, loss, label='Training loss')
# plt.plot(np.arange(0, N), H.history["val_accuracy"], label="VA")
plt.plot(np.arange(0, len(val_loss)), val_loss, label='VS')

plt.plot(epochs, loss, label='TL')
#plt.plot(np.arange(0, N), H.history["val_accuracy"], label="validation accuracy")
plt.plot(np.arange(0, N), val_loss, label='VS')
#plt.plot(epochs, acc, 'bo', label='Training acc')
#plt.plot(1, val_acc, 'b', label='Validation acc')
#plt.title('Training and validation accuracy')
plt.xlabel('Epochs',fontsize=16, fontdict=dict(weight='bold'))
    # y label
plt.ylabel('Accuracy/Loss', fontsize=16, fontdict=dict(weight='bold'))
#plt.ylabel("Accuracy")
#plt.xlabel("Epochs")
plt.xticks( rotation=0, weight = 'bold' )
plt.yticks( rotation=0, weight = 'bold')
plt.tick_params(rotation=0,axis='y', labelsize=14)
plt.tick_params(rotation=0,axis='x', labelsize=14)
#plt.grid('white')
#plt.grid(axis='x', color='0.95')
plt.legend(loc='best')
plt.legend(prop={'size':12})
#fig = plt.figure(figsize = (4, 3))
plt.savefig('ACC',dpi=200, bbox_inches='tight')
plt.show()

wandb.init()

# Log accuracy/loss plot to W&B
wandb.log({"Accuracy_Loss_Plot": wandb.Image(plt)})

# %%
# Finish W&B run
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▂▁▃█▄▄█▅█▁▆▃▄▄▅▅▅▆▃▆█▇▇█▇█▇█▇██▇██▆█▇███</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▂▂▃▃▃▄▁▂▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇████</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>▄▃▃▃▃▃▃▂▃█▃▆▄▃▂▃▂▂▂▁▁▁▂▁▁▂▁▁▁▁▁▂▁▁▁▁▁▃▂▁</td></tr><tr><td>epoch/val_accuracy</td><td>▄█▁▇▅▅█▅█▆▄▄▄▄▅▇▇▆▆▆▆▆▆▆▆▆▇▇▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>epoch/val_loss</td><td>▂▁▂▁▁▁▁▂▆█▂▂▂▁▁▁▁▁▁▂▁▁▂▁▁▁▁▂▂▂▂▂▂▁▁▁▁▂▂▁</td></tr><tr><td>test_accuracy</td><td>█▁</td></tr><tr><td>test_sensitivity</td><td>█▁</td></tr><tr><td>test_specificity</td><td>▁▁</td></tr><tr><td>train_accuracy</td><td>▁█</td></tr><tr><td>train_sensitivity</td><td>▁█</td></tr><tr><td>train_specificity</td><td>▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>1</td></tr><tr><td>epoch/epoch</td><td>99</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.002</td></tr><tr><td>epoch/val_accuracy</td><td>0.77778</td></tr><tr><td>epoch/val_loss</td><td>0.50827</td></tr><tr><td>test_accuracy</td><td>0.77778</td></tr><tr><td>test_sensitivity</td><td>0.88889</td></tr><tr><td>test_specificity</td><td>0.66667</td></tr><tr><td>train_accuracy</td><td>0.97222</td></tr><tr><td>train_sensitivity</td><td>0.94737</td></tr><tr><td>train_specificity</td><td>1</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dnyaboke_project_trial5</strong> at: <a href='https://wandb.ai/delta-group-50/final-project-ablations/runs/gnb01le6' target="_blank">https://wandb.ai/delta-group-50/final-project-ablations/runs/gnb01le6</a><br> View project at: <a href='https://wandb.ai/delta-group-50/final-project-ablations' target="_blank">https://wandb.ai/delta-group-50/final-project-ablations</a><br>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20250316_195344-gnb01le6/logs</code>
